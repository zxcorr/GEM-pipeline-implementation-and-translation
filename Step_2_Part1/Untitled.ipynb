# %%
Dir1 = "/media/nicolli/eabdalla2012/resultados_nicolli/tradução_gem_modulos/Step_1_files/dat/"
azimut = []
    
with open(Dir1 + "99_05_1820234490.dat", "r+") as f: 
    input_data = f.readlines()
    n_lines = len(input_data)


for line in input_data:
    input_line = line.replace(" ", "")
    input_line = line.replace("\n", "")
    input_line = input_line.split(" ")
    input_line = list(filter(None, input_line))
    jazimut = float(input_line[4])

    azimut.append(jazimut)

# %%
comp = len(azimut)
for i in range(comp):
    
    if i+3 < comp: 
    
        if abs(azimut[i+1]-azimut[i]) > 176:

            print("azi[i]", azimut[i])

            if azimut[i+3] < azimut[i+2]:

                print("exclui azi[i+1]",azimut[i+1])
                print("\n\n")
            else:

                print("exclui azi[i+1] e azi[i+2]")
                print("\n\n")
# Out:
# azi[i] 74.284
# exclui azi[i+1] 343.18
#
#
#
# azi[i] 116.646
# exclui azi[i+1] 354.442
#
#
#
# azi[i] 159.385
# exclui azi[i+1] 354.764
#
#
#
# azi[i] 1.187
# exclui azi[i+1] 199.639
#
#
#
# azi[i] 0.655
# exclui azi[i+1] 238.772
#
#
#
# azi[i] 0.222
# exclui azi[i+1] 276.375
#
#
#
# azi[i] 31.866
# exclui azi[i+1] 315.375
#
#
#
# azi[i] 89.784
# exclui azi[i+1] 351.047
#
#
#
# azi[i] 142.487
# exclui azi[i+1] 354.819
#
#
#
# azi[i] 1.254
# exclui azi[i+1] 189.92
#
#
#
# azi[i] 0.766
# exclui azi[i+1] 234.845
#
#
#
# azi[i] 0.155
# exclui azi[i+1] 278.294
#
#
#
# azi[i] 37.924
# exclui azi[i+1] 319.602
#
#
#
# azi[i] 95.864
# exclui azi[i+1] 352.544
#
#
#
# azi[i] 149.632
# exclui azi[i+1] 354.786
#
#
#
# azi[i] 1.287
# exclui azi[i+1] 199.384
#
#
#
# azi[i] 0.599
# exclui azi[i+1] 244.797
#
#
#
# azi[i] 0.067
# exclui azi[i+1] 287.281
#
#
#
# azi[i] 49.053
# exclui azi[i+1] 327.125
#
#
#
# azi[i] 107.192
# exclui azi[i+1] 353.987
#
#
#
# azi[i] 160.827
# exclui azi[i+1] 354.752
#
#
#
# azi[i] 1.043
# exclui azi[i+1] 210.801
#
#
#
# azi[i] 0.388
# exclui azi[i+1] 261.263
#
#
#
# azi[i] 19.306
# exclui azi[i+1] 307.453
#
#
#
# azi[i] 80.397
# exclui azi[i+1] 347.518
#
#
#
# azi[i] 143.741
# exclui azi[i+1] 354.764
#
#
#
# azi[i] 1.154
# exclui azi[i+1] 200.915
#
#
#
# azi[i] 0.499
# exclui azi[i+1] 253.33
#
#
#
# azi[i] 9.686
# exclui azi[i+1] 301.073
#
#
#
# azi[i] 76.736
# exclui azi[i+1] 345.355
#
#
#
# azi[i] 138.981
# exclui azi[i+1] 354.841
#
#
#
# azi[i] 1.232
# exclui azi[i+1] 196.488
#
#
#
# azi[i] 0.51
# exclui azi[i+1] 251.787
#
#
#
# azi[i] 11.484
# exclui azi[i+1] 302.338
#
#
#
# azi[i] 78.278
# exclui azi[i+1] 346.453
#
#
#
# azi[i] 138.282
# exclui azi[i+1] 354.875
#
#
#
# azi[i] 1.22
# exclui azi[i+1] 195.001
#
#
#
# azi[i] 0.566
# exclui azi[i+1] 249.258
#
#
#
# azi[i] 1.72
# exclui azi[i+1] 296.002
#
#
#
# azi[i] 67.427
# exclui azi[i+1] 339.485
#
#
#
# azi[i] 126.41
# exclui azi[i+1] 354.719
#
#
#
# azi[i] 1.376
# exclui azi[i+1] 181.387
#
#
#
# azi[i] 0.754
# exclui azi[i+1] 234.945
#
#
#
# azi[i] 0.089
# exclui azi[i+1] 283.454
#
#
#
# azi[i] 53.557
# exclui azi[i+1] 330.62
#
#
#
# azi[i] 112.629
# exclui azi[i+1] 354.331
#
#
#
# azi[i] 165.987
# exclui azi[i+1] 354.73
#
#
#
# azi[i] 0.954
# exclui azi[i+1] 218.113
#
#
#
# azi[i] 0.322
# exclui azi[i+1] 265.867
#
#
#
# azi[i] 23.522
# exclui azi[i+1] 310.97
#
#
#
# azi[i] 85.035
# exclui azi[i+1] 349.981
#
#
#
# azi[i] 138.792
# exclui azi[i+1] 354.786
#
#
#
# azi[i] 1.32
# exclui azi[i+1] 186.768
#
#
#
# azi[i] 0.777
# exclui azi[i+1] 233.569
#
#
#
# azi[i] 0.233
# exclui azi[i+1] 276.874
#
#
#
# azi[i] 34.573
# exclui azi[i+1] 318.792
#
#
#
# azi[i] 91.171
# exclui azi[i+1] 351.89
#
#
#
# azi[i] 143.663
# exclui azi[i+1] 354.808
#
#
#
# azi[i] 1.309
# exclui azi[i+1] 191.562
#
#
#
# azi[i] 0.71
# exclui azi[i+1] 240.115
#
#
#
# azi[i] 0.1
# exclui azi[i+1] 285.739
#
#
#
# azi[i] 49.552
# exclui azi[i+1] 328.989
#
#
#
# azi[i] 109.245
# exclui azi[i+1] 354.198
#
#
#
# azi[i] 171.945
# exclui azi[i+1] 354.653
#
#
#
# azi[i] 0.865
# exclui azi[i+1] 225.602
#
#
#
# azi[i] 0.233
# exclui azi[i+1] 275.809
#
#
#
# azi[i] 38.568
# exclui azi[i+1] 322.154
#
#
#
# azi[i] 99.825
# exclui azi[i+1] 353.521
#
#
#
# azi[i] 157.565
# exclui azi[i+1] 354.775
#
#
#
# azi[i] 1.054
# exclui azi[i+1] 212.421
#
#
#
# azi[i] 0.388
# exclui azi[i+1] 263.171
#
#
#
# azi[i] 17.719
# exclui azi[i+1] 308.562
#
#
#
# azi[i] 79.887
# exclui azi[i+1] 348.761
#
#
#
# azi[i] 136.074
# exclui azi[i+1] 354.863
#
#
#
# azi[i] 1.298
# exclui azi[i+1] 188.355
#
#
#
# azi[i] 0.732
# exclui azi[i+1] 237.153
#
#
#
# azi[i] 0.122
# exclui azi[i+1] 284.463
#
#
#
# azi[i] 44.748
# exclui azi[i+1] 326.726
#
#
#
# azi[i] 104.574
# exclui azi[i+1] 353.987
#
#
#
# azi[i] 164.067
# exclui azi[i+1] 354.686
#
#
#
# azi[i] 0.999
# exclui azi[i+1] 217.769
#
#
#
# azi[i] 0.355
# exclui azi[i+1] 267.332
#
#
#
# azi[i] 23.056
# exclui azi[i+1] 312.668
#
#
#
# azi[i] 85.423
# exclui azi[i+1] 351.002
#
#
#
# azi[i] 142.365
# exclui azi[i+1] 354.863
#
#
#
# azi[i] 1.22
# exclui azi[i+1] 196.821
#
#
#
# azi[i] 0.599
# exclui azi[i+1] 246.806
#
#
#
# azi[i] 0.033
# exclui azi[i+1] 296.202
#
#
#
# azi[i] 62.922
# exclui azi[i+1] 338.897
#
#
#
# azi[i] 122.726
# exclui azi[i+1] 354.741
#
#
#
# azi[i] 1.431
# exclui azi[i+1] 179.29
#
#
#
# azi[i] 0.832
# exclui azi[i+1] 229.807
#
#
#
# azi[i] 0.244
# exclui azi[i+1] 277.096
#
#
#
# azi[i] 37.979
# exclui azi[i+1] 322.809
#
#
#
# azi[i] 104.041
# exclui azi[i+1] 354.009
#
#
#
# azi[i] 164.7
# exclui azi[i+1] 354.719
#
#
#
# azi[i] 0.954
# exclui azi[i+1] 220.066
#
#
#
# azi[i] 0.322
# exclui azi[i+1] 270.45
#
#
#
# azi[i] 28.193
# exclui azi[i+1] 316.529
#
#
#
# azi[i] 92.813
# exclui azi[i+1] 352.633
#
#
#
# azi[i] 154.137
# exclui azi[i+1] 354.786
#
#
#
# azi[i] 1.043
# exclui azi[i+1] 210.579
#
#
#
# azi[i] 0.411
# exclui azi[i+1] 262.572
#
#
#
# azi[i] 17.02
# exclui azi[i+1] 309.428
#
#
#
# azi[i] 80.186
# exclui azi[i+1] 349.493
#
#
#
# azi[i] 136.861
# exclui azi[i+1] 354.808
#
#
#
# azi[i] 1.276
# exclui azi[i+1] 195.534
#
#
#
# azi[i] 0.621
# exclui azi[i+1] 247.682
#
#
#
# azi[i] 0.011
# exclui azi[i+1] 297.434
#
#
#
# azi[i] 66.617
# exclui azi[i+1] 342.07
#
#
#
# azi[i] 130.748
# exclui azi[i+1] 354.841
#
#
#
# azi[i] 1.276
# exclui azi[i+1] 189.609
#
#
#
# azi[i] 0.644
# exclui azi[i+1] 246.584
#
#
#
# azi[i] 2.918
# exclui azi[i+1] 300.441
#
#
#
# azi[i] 75.837
# exclui azi[i+1] 347.785
#
#
#
# azi[i] 138.592
# exclui azi[i+1] 354.841
#
#
#
# azi[i] 1.298
# exclui azi[i+1] 196.388
#
#
#
# azi[i] 0.655
# exclui azi[i+1] 248.625
#
#
#
# azi[i] 1.797
# exclui azi[i+1] 299.853
#
#
#
# azi[i] 68.214
# exclui azi[i+1] 343.324
#
#
#
# azi[i] 127.597
# exclui azi[i+1] 354.83
#
#
#
# azi[i] 1.398
# exclui azi[i+1] 182.12
#
#
#
# azi[i] 0.777
# exclui azi[i+1] 234.523
#
#
#
# azi[i] 0.2
# exclui azi[i+1] 282.976
#
#
#
# azi[i] 42.939
# exclui azi[i+1] 327.136
#
#
#
# azi[i] 103.509
# exclui azi[i+1] 354.076
#
#
#
# azi[i] 165.166
# exclui azi[i+1] 354.741
#
#
#
# azi[i] 0.932
# exclui azi[i+1] 222.95
#
#
#
# azi[i] 0.311
# exclui azi[i+1] 275.909
#
#
#
# azi[i] 39.733
# exclui azi[i+1] 325.161
#
#
#
# azi[i] 103.953
# exclui azi[i+1] 354.065
#
#
#
# azi[i] 165.465
# exclui azi[i+1] 354.73
#
#
#
# azi[i] 0.976
# exclui azi[i+1] 221.197
#
#
#
# azi[i] 0.244
# exclui azi[i+1] 274.544
#
#
#
# azi[i] 33.797
# exclui azi[i+1] 321.422
#
#
#
# azi[i] 97.04
# exclui azi[i+1] 353.543
#
#
#
# azi[i] 165.787
# exclui azi[i+1] 354.708
#
#
#
# azi[i] 0.976
# exclui azi[i+1] 221.608
#
#
#
# azi[i] 0.233
# exclui azi[i+1] 277.451
#
#
#
# azi[i] 39.5
# exclui azi[i+1] 325.361
#
#
#
# azi[i] 106.327
# exclui azi[i+1] 354.309
#
#
#
# azi[i] 169.815
# exclui azi[i+1] 354.741
#
#
#
# azi[i] 0.865
# exclui azi[i+1] 230.174
#
#
#
# azi[i] 0.288
# exclui azi[i+1] 275.864
#
#
#
# azi[i] 31.3
# exclui azi[i+1] 320.401
#
#
#
# azi[i] 92.547
# exclui azi[i+1] 353.21
#
#
#
# azi[i] 150.353
# exclui azi[i+1] 354.841
#
#
#
# azi[i] 1.121
# exclui azi[i+1] 204.543
#
#
#
# azi[i] 0.544
# exclui azi[i+1] 253.851
#
#
#
# azi[i] 1.209
# exclui azi[i+1] 300.596
#
#
#
# azi[i] 64.764
# exclui azi[i+1] 341.993
#
#
#
# azi[i] 123.27
# exclui azi[i+1] 354.863
#
#
#
# azi[i] 1.498
# exclui azi[i+1] 177.781
#
#
#
# azi[i] 177.781
# exclui azi[i+1] 354.664
#
#
#
# azi[i] 0.865
# exclui azi[i+1] 229.708
